# %% [markdown]
# <a href="https://colab.research.google.com/github/pacomm5/PLANTILLAS2/blob/main/Excel_abrir.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# - esto abriendo una consulta dentro de un excel.
# - lo he subido a colab y luego lo he abierto.
# - tengo que poner el nombre de la pestaña.

# %%
xlsx = pd.ExcelFile("/content/U382 IMPORTADO.xlsx")
df = pd.read_excel(xlsx, "U382_IMPORTADO" )

# %%
df.head()
# Out:
#    Tall  Referencia   Fecha Fa   Fec.aper Cta.car           Nombre cliente  \
# 0     1     9475471 2017-03-16 2017-03-15  144648     FTC DEQUER ENGINE SL
# 1     6     7823171 2015-02-10 2015-02-10  131646          MOHAMED GOUGRID
# 2     2     9610441 2017-05-11 2017-05-10    116W  ORDENES DE REPARACION G
# 3     2     8017152 2015-05-25 2015-05-21     NaN  ORDENES DE REPARACION G
# 4     2     8017151 2015-05-25 2015-05-21    2291    VOLKSWAGEN RENTING SA
#
#     Cta.tit         Nombre titular  Recamb.  Tiem.fac  Total.MO      Modelo  \
# 0  144648.0   FTC DEQUER ENGINE SL     0.00      0.84     67.20   A6 C6 3.0
# 1  131646.0        MOHAMED GOUGRID    42.66      0.50     38.50  AUDI Q5 AD
# 2  104249.0    PEIRO SOLER LEANDRO     3.13      0.60     38.00  PASSAT EDI
# 3    2291.0  VOLKSWAGEN RENTING SA    24.12      0.50     31.66  PASSAT EDI
# 4    2291.0  VOLKSWAGEN RENTING SA   161.85      1.60    105.12  PASSAT EDI
#
# ...
